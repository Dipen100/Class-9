# %% [markdown]
# ### 1. Very Short Answer Questions:

# %% [markdown]
# **a. HTML stands for HyperText Markup Language which is used to create and design web pages.**

# %% [markdown]
# **b.HTML stands for HyperText Markup Language.**

# %% [markdown]
# **c.HTML was created by Tim Berners Lee in 1991.**

# %% [markdown]
# **d. The purpose of HTML is to create and design web pages.**

# %% [markdown]
# **e. HTML document has a rigid structure where complete web page is enclosed within <HTML>...</HTML> dividing it into two sections i.e Document head (<HEAD>...</HEAD>) and Document body (<BODY>...</BODY>).**

# %% [markdown]
# **f. A tag in HTML are the instructions which tells browser that it should do something.**

# %% [markdown]
# **g. An example of HTML tag is &lt;img&gt;**

# %% [markdown]
# **h. The opening tag in HTML marks that the start of an element and closing tag marks the end of an element.**

# %% [markdown]
# **i.An attribute is extra information added inside an element's opening tag to define its properties.**

# %% [markdown]
# **j. An example of HTML atribute is:
#     &lt;img src="./Images/hero.jpg" alt="figure"&gt;
#     src and alt are attributes of img.**

# %% [markdown]
# **k.The purpose of &lt;head&gt; tag is to give heading in HTML.**

# %% [markdown]
# **l.The purpose of &lt;title&gt; tag in HTML is to give title of our webpage.**

# %% [markdown]
# **m. The purpose of &lt;body&gt; tag in HTML is to show visible contents of our webpage i.e everything we see in the browser window.**

# %% [markdown]
# **n. The &lt;h1&gt; tag in HTML is used for giving the highest heading in our webpage.**

# %% [markdown]
# **o. We can create a hyperlink in HTML by using &lt;a&gt; tag.**

# %% [markdown]
# **p. The &lt;a&gt; tag is used in HTML for giving link to multiple pages in our webpage.**

# %% [markdown]
# **q. By using &lt;img&gt; tag we can add an image to a webpage in HTML.**

# %% [markdown]
# **r. The &lt;img&gt; tag in HTML is used to insert an image in our webpage.**

# %% [markdown]
# **s. The purpose of &lt;p&gt; tag in HTML is to write paragraph in our webpage.**

# %% [markdown]
# **t. To create ordered list we use &lt;ol&gt; tag and to create unordered list we use &lt;ul&gt; tag.**

# %% [markdown]
# **u. The &lt;ul&gt; tag in HTML is used for creating unordered list.**

# %% [markdown]
# **v. The &lt;ol&gt; tag in HTML is used for creating ordered list.**

# %% [markdown]
# **w. The purpose of &lt;li&gt; tag in HTML is to create a list of items for both ordered and unordered list.**

# %% [markdown]
# **x. By using &lt;table&gt; tag we can create table in HTML.
# eg:- &lt;table&gt;...&lt;/table&gt;**

# %% [markdown]
# **y. To create a table in our webpage &lt;table&gt; tag is used.**

# %% [markdown]
# **z. The &lt;tr&gt; tag in HTML is used to indicate rows of a table.
# eg:- &lt;tr&gt;...&lt;/tr&gt;**

# %% [markdown]
# **aa. The &lt;td&gt; tag in HTMl is used to write description inside our table.
# eg:- &lt;td&gt;...&lt;/td&gt;**

# %% [markdown]
# **ab. The &lt;th&gt; tag in HTML is used to give heading in a table.
# eg:- &lt;/th&gt;...&lt;/th&gt;**

# %% [markdown]
# **ac. The purpose of &lt;form&gt; tag in HTML is to create a submitable form inside our webpage.
# eg:- &lt;/form&gt;...&lt;/form&gt;**

# %% [markdown]
# **ad. We can create a text input field in HTML by using &lt;input&gt; tag with attribute type="text" inside it.
# eg:- &lt;input type="text"&gt;**
