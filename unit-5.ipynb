# %% [markdown]
# ### 1. Write the very short answers to the following questions: ###

# %% [markdown]
# **a. The internet is a global network connecting millions of computers for sharing information.**

# %% [markdown]
# **b. Any two social media platforms are Facebook and Instagram.**

# %% [markdown]
# **c. The primary use of a search engine is to help users find information online through keywords.**

# %% [markdown]
# **d. WWW stands for World Wide Wave.**

# %% [markdown]
# **e. A web browser is like a tool for accessing the internet and retrieving the information on the WWW.**

# %% [markdown]
# **f. An example of remote login software is Anydesk.**

# %% [markdown]
# **g. Gmail is one of the email service provider.**

# %% [markdown]
# **h. URL is an address which is used to access online resources.**

# %% [markdown]
# **i. FTP (File Transfer Protocol) is an example of a web protocol.**

# %% [markdown]
# **j. The main purpose of email is to send and receive messages electronically over the internet.**

# %% [markdown]
# **k. The role of video conferencing is to help people communicate remotely.**

# %% [markdown]
# **l. One advantage of social media is instant communication.**

# %% [markdown]
# **m. A blog is a website or online platform where individuals or groups regularly post content in articles, posts or entries.**

# %% [markdown]
# **n. Zoom is video conferencing tool.**

# %% [markdown]
# ### 2. Write the short answers to the following questions. ###

# %% [markdown]
# **a. The internet is a global network connecting millions of computers for sharing data or information. It is important as it allows people to share and access information from anywhere in the world and makes communication faster, helps people find information easily and also allows people to entertain.**

# %% [markdown]
# **b. Social media is a platform for instant communication, enabling people to stay connected together remotely. It has changed the way of communication as it fosters online communities, offers educational resources, and provides entertainment. It also creates job opportunities which makes people life easier.**

# %% [markdown]
# **c. Search engine works by finding and showing information from the internet. It uses a special programs called web crawlers to collect data from web pages, stores them in a large database and when user types a query it searches the index to show most relevant results.**

# %% [markdown]
# **d. The function of web browser is to access data from the web servers on private networks or interact with files in file systems and serves it to the user when user asks for the information.**

# %% [markdown]
# **e. Remote login works by allowing a user to access another computer through a network or the internet. The user enters a username and password using software like Telnet or SSH and after connecting it, users can achieve remote login and use computer remotely.**

# %% [markdown]
# **f. The advantages of email over traditional email are:**
# 1. Emails are fast, inexpensive and easy to use or communicate.
# 2. Users can send or receive emails from anywhere as long as they have an intenet connection.

# %% [markdown]
# **g. In business, video conferencing plays an important part of communication tools for messaging and calling. Companies uses different types of video conferencing tools to business applications like online healthcare, customer support and distance learning. Business need extra features such as screen sharing and recording which is provided by video conferencing tools.**

# %% [markdown]
# **h. URLs help in browsing the internet by giving exact address of a webpage. When we type a URL in a web browser, it tells the browser where to find the website on the internet, so the correct page or file is loaded and displayed on the screen.**

# %% [markdown]
# **i. Two benefits of using HTTPS instead of HTTP are:**
# 1. It encrypts the data, keeping safe from hackers.
# 2. Websites using HTTPS are more trustworthy.

# %% [markdown]
# **Q.No j, k, n, o. DO YOURSELF**

# %% [markdown]
# **l. Roles of protocols are:**
# 1. It ensures accurate and reliable communication between computers.
# 2. They also helps different devices and networks understand each other and work smoothly.

# %% [markdown]
# **m. Email improves workspace communication by allowing quick and easy exchange of messages and files between employees. It helps in sharing information instantly and communicating with multiple people at the same time which helps in improving productivity.**
